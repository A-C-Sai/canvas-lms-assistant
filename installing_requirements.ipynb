# %%
! pip3 install ipykernel ipywidgets python-dotenv

# %%
! pip3 install langchain-classic langchain langchain-core langchain-community langchain-text-splitters langchain-huggingface langchain-chroma langchain-openai langchain-aws langchain-ollama

# %%
! pip3 install "numpy<2" pandas transformers sentence-transformers torch tiktoken

# %%
! pip3 install chromadb faiss-cpu ollama

# %%
! pip3 install beautifulsoup4

# %%
! pip3 install pydantic pypdf

# %%
! pip3 install boto3

# %%
! pip3 install langgraph langgraph-checkpoint-sqlite

# %%
! pip3 install streamlit

# %%
! pip3 install watchdog # for live streamlit reaload

# %%
! pip3 install deepeval
