# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
questions_data_student_guide = pd.read_csv('../data/datasets/synthetic_dataset-student-guide.csv', usecols=['input'])

# %%
eval_que_set_1 = questions_data_student_guide.sample(50)

# %%
eval_que_set_1
# Out:
#                                                                                                                                                  input
# 125       How do I view Canvas Pages using the Pages Index or via Modules, and what should I do if the Pages link is hidden from my course navigation?
# 136                                          How can a student view all course users on the People page, including those with Pending status, by role?
# 61                                                     How do I submit a Canvas peer review with Enhanced Rubrics when the Assignments link is hidden?
# 40                                                                          How can I view rubric results and rubric comments for a Canvas assignment?
# 156                                                                 How can I view one question at a time using the Question Navigator in New Quizzes?
# ...

# %%
eval_que_set_1.index
# Out:
# Index([125, 136,  61,  40, 156,  94,  98,  45, 126,  48,  76,  20, 112, 113,
#         70,  99, 154,  75,  10,  86, 143,  47, 109,  43, 153,  22,  66,  55,
#          3,  44,  21,  17, 102,  62, 149,  12, 110,  69, 163,   5,  60, 124,
#        120,  72,  29,  26,  67,  78,  18,  49],
#       dtype='int64')

# %%
questions_data_basics_guide = pd.read_csv('../data/datasets/synthetic_dataset-basics-guide.csv', usecols=['input'])

# %%
eval_que_set_2 = questions_data_basics_guide.sample(50)

# %%
eval_que_set_2
# Out:
#                                                                                                                                                                                                                                                                   input
# 121                                                                                                                                 How can a Canvas account administrator use the Help menu in the global navigation to reopen a dismissed to-do item and complete it?
# 457                                                                                                             How are entries in the Homeroom IDs section sorted by due date or event date, how are their icons and subject names displayed, and how can I open them?
# ...

# %%
eval_que_set_2.index
# Out:
# Index([121, 457, 390, 274,  89, 372, 242, 362, 173, 166, 385, 245, 161, 445,
#        325, 241, 416, 324, 101, 255, 382,  25,  97, 138, 298,  52, 347, 280,
#         94, 338, 240, 127, 331, 278,  64, 177, 139, 229,   1, 244, 189, 352,
#        394,  32, 232, 157, 318,  66, 330, 423],
#       dtype='int64')
