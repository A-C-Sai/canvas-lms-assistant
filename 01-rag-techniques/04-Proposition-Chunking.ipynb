# %% [markdown]
# - propositions are small, self-contained pieces of information.
# - individual facts or claims that can stand on their own
#
# - key characteristics:
#     - contain a single piece of info
#     - can be understood without additional context; self-contained
#     - state a clear fact or claim
#     - consise and to the point
#     - include any necessary context within themselves
#
# - instead of a paragraph about the `Leaning tower of pisa`, we might have propositions like:
#     - The Leaning tower of Pisa is 55.86 metres ( 183 feet 3 inches).
#     - The Leaning tower of Pisa is known for its nearly 40 degree lean.
#     - The Leaning tower of Pisa has 296 steps

# %% [markdown]
# - some drawbacks of traditional methods of splitting text into chunks like paragraphs or sentences:
#     - important info might be split across multiple chunks
#     - chunks may contain irrelevant info along with the relevant info
#     - harder to pinpoint exactly the info needed to answer a specific question.
#
# - propositions aim to address these issues by breaking info down to its smallest meaningful parts.
# - using propositions allows for finer control and better handling of specific queries, especially for extracting knowledge from detailed or complex texts.
# - by breaking the document into small factual propositions, the system allows for highly specific retrieval, making it easier to extract precise answers from large or complex documents.
# - more accurate AI responses due to more precise input info.

# %% [markdown]
# ```mermaid
# graph LR
# A(prepare your data) --> B(generate propositions) --> C(check quality) --> D(index the propositions) --> E(retrieval) --> F(use in your system)
# ```

# %% [markdown]
# ### Preparing Data

# %%
sample_content = """The Leaning Tower of Pisa, or simply the Tower of Pisa (torre di Pisa), is the campanile, or freestanding bell tower, of Pisa Cathedral. It is known for its nearly four-degree lean, the result of an unstable foundation. The tower is one of three structures in Pisa's Cathedral Square (Piazza del Duomo), which includes the cathedral and Pisa Baptistry. Over time, the tower has become one of the most visited tourist attractions in the world as well as an architectural icon of Italy, receiving over 5 million visitors each year.

The height of the tower is 55.86 metres (183 feet 3 inches) from the ground on the low side and 56.67 m (185 ft 11 in) on the high side. The width of the walls at the base is 2.44 m (8 ft 0 in). Its weight is estimated at 14,500 tonnes (16,000 short tons). The tower has 296 or 294 steps; the seventh floor has two fewer steps on the north-facing staircase.

The tower began to lean during construction in the 12th century, due to soft ground which could not properly support the structure's weight. It worsened through the completion of construction in the 14th century. By 1990, the tilt had reached 5.5 degrees. The structure was stabilized by remedial work between 1993 and 2001, which reduced the tilt to 3.97 degrees.

The identity of the architect of the tower is a subject of controversy. The design had long been attributed to a man named Guglielmo and to Bonanno Pisano, the latter a well-known 12th-century resident artist of Pisa known for his bronze casting, particularly in the Pisa Duomo. Pisano left Pisa in 1185 for Monreale, Sicily, only to return and die in his home town. A piece of cast bearing his name was discovered at the foot of the tower in 1820, but this may be related to the bronze door in the façade of the cathedral that was destroyed in 1595. A 2001 study seems to indicate Diotisalvi was the original architect, due to the time of construction and affinity with other Diotisalvi works, notably the bell tower of San Nicola and the Baptistery, both in Pisa.

The tower has survived at least four strong earthquakes since 1280. A 2018 engineering investigation concluded that the tower withstood the tremors because of dynamic soil-structure interaction: the height and stiffness of the tower combined with the softness of the foundation soil influences the tower's vibrational characteristics in such a way that it does not resonate with earthquake ground motion. The same soft soil that caused the leaning and brought the tower to the verge of collapse helped to prevent significant destruction in the event of an earthquake.
"""

# %% [markdown]
# ### Chunking

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

# %%
docs_list = [Document(page_content=sample_content, metadata={"Title":"Leaning Tower of Pisa", "Source":"https://en.wikipedia.org/wiki/Leaning_Tower_of_Pisa"})]

# %%
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=256, chunk_overlap=64)

# %%
chunks = text_splitter.split_documents(docs_list)

# %%
chunks
# Out:
# [Document(metadata={'Title': 'Leaning Tower of Pisa', 'Source': 'https://en.wikipedia.org/wiki/Leaning_Tower_of_Pisa'}, page_content="The Leaning Tower of Pisa, or simply the Tower of Pisa (torre di Pisa), is the campanile, or freestanding bell tower, of Pisa Cathedral. It is known for its nearly four-degree lean, the result of an unstable foundation. The tower is one of three structures in Pisa's Cathedral Square (Piazza del Duomo), which includes the cathedral and Pisa Baptistry. Over time, the tower has become one of the most visited tourist attractions in the world as well as an architectural icon of Italy, receiving over 5 million visitors each year.\n\nThe height of the tower is 55.86 metres (183 feet 3 inches) from the ground on the low side and 56.67 m (185 ft 11 in) on the high side. The width of the walls at the base is 2.44 m (8 ft 0 in). Its weight is estimated at 14,500 tonnes (16,000 short tons). The tower has 296 or 294 steps; the seventh floor has two fewer steps on the north-facing staircase."),
#  Document(metadata={'Title': 'Leaning Tower of Pisa', 'Source': 'https://en.wikipedia.org/wiki/Leaning_Tower_of_Pisa'}, page_content="The tower began to lean during construction in the 12th century, due to soft ground which could not properly support the structure's weight. It worsened through the completion of construction in the 14th century. By 1990, the tilt had reached 5.5 degrees. The structure was stabilized by remedial work between 1993 and 2001, which reduced the tilt to 3.97 degrees."),
#  Document(metadata={'Title': 'Leaning Tower of Pisa', 'Source': 'https://en.wikipedia.org/wiki/Leaning_Tower_of_Pisa'}, page_content='The identity of the architect of the tower is a subject of controversy. The design had long been attributed to a man named Guglielmo and to Bonanno Pisano, the latter a well-known 12th-century resident artist of Pisa known for his bronze casting, particularly in the Pisa Duomo. Pisano left Pisa in 1185 for Monreale, Sicily, only to return and die in his home town. A piece of cast bearing his name was discovered at the foot of the tower in 1820, but this may be related to the bronze door in the façade of the cathedral that was destroyed in 1595. A 2001 study seems to indicate Diotisalvi was the original architect, due to the time of construction and affinity with other Diotisalvi works, notably the bell tower of San Nicola and the Baptistery, both in Pisa.'),
#  Document(metadata={'Title': 'Leaning Tower of Pisa', 'Source': 'https://en.wikipedia.org/wiki/Leaning_Tower_of_Pisa'}, page_content="The tower has survived at least four strong earthquakes since 1280. A 2018 engineering investigation concluded that the tower withstood the tremors because of dynamic soil-structure interaction: the height and stiffness of the tower combined with the softness of the foundation soil influences the tower's vibrational characteristics in such a way that it does not resonate with earthquake ground motion. The same soft soil that caused the leaning and brought the tower to the verge of collapse helped to prevent significant destruction in the event of an earthquake.")]

# %%
for i, doc in enumerate(chunks):
    doc.metadata['chunk_id'] = i+1

# %% [markdown]
# ### Generate Propositions

# %%
from pydantic import BaseModel, Field
from langchain_core.prompts import FewShotChatMessagePromptTemplate, ChatPromptTemplate
#from langchain_ollama import ChatOllama
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
# data model
class GeneratePropositions(BaseModel):
    """List of all the propositions in a given document"""

    propositions: list[str] = Field(description="List of propositions (factual, self-contained, consise information)")

# %%
structured_llm = ChatOpenAI(model="gpt-5-mini", temperature=0).with_structured_output(GeneratePropositions)

# %%
proposition_example = [
    {
        "document": "In 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.",
        "propositions": "['Neil Armstrong was an astronaut.', 'Neil Armstrong walked on the Moon in 1969.', 'Neil Armstrong was the first person to walk on the Moon.', 'Neil Armstrong walked on the Moon during the Apollo 11 mission.', 'The Apollo 11 mission occurred in 1969.']"
    },
]

# %%
proposition_prompt_example = ChatPromptTemplate([
    ('human', "Example Document:\n{document}"),
    ('ai',"Example Propositions:\n{propositions}")
])

# %%
few_shot_prompt = FewShotChatMessagePromptTemplate(
    examples=proposition_example,
    example_prompt=proposition_prompt_example # This is a prompt template used to format each individual example.
)

# %%
few_shot_prompt
# Out:
# FewShotChatMessagePromptTemplate(examples=[{'document': 'In 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.', 'propositions': "['Neil Armstrong was an astronaut.', 'Neil Armstrong walked on the Moon in 1969.', 'Neil Armstrong was the first person to walk on the Moon.', 'Neil Armstrong walked on the Moon during the Apollo 11 mission.', 'The Apollo 11 mission occurred in 1969.']"}], input_variables=[], input_types={}, partial_variables={}, example_prompt=ChatPromptTemplate(input_variables=['document', 'propositions'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['document'], input_types={}, partial_variables={}, template='Example Document:\n{document}'), additional_kwargs={}), AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=['propositions'], input_types={}, partial_variables={}, template='Example Propositions:\n{propositions}'), additional_kwargs={})]))

# %%
few_shot_prompt.invoke({}).messages
# Out:
# [HumanMessage(content='Example Document:\nIn 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Example Propositions:\n['Neil Armstrong was an astronaut.', 'Neil Armstrong walked on the Moon in 1969.', 'Neil Armstrong was the first person to walk on the Moon.', 'Neil Armstrong walked on the Moon during the Apollo 11 mission.', 'The Apollo 11 mission occurred in 1969.']", additional_kwargs={}, response_metadata={})]

# %%
system = """Please break down the following text into simple, self-contained propositions. Ensure that each proposition meets the following criteria:

    1. (Important) Express a Single Fact: Each proposition should state one specific fact or claim.
    2. (Important) Be Understandable Without Context: The proposition should be self-contained, meaning it can be understood without needing additional context.
    3. (Important) Use Full Names, Not Pronouns: Avoid pronouns or ambiguous references; use full entity names.
    4. (Important) Include Relevant Dates/Qualifiers: If applicable, include necessary dates, times, and qualifiers to make the fact precise.
    5. (Important) Contain One Subject-Predicate Relationship: Focus on a single subject and its corresponding action or attribute, without conjunctions or multiple clauses.
"""

# %%
final_propositions_prompt = ChatPromptTemplate([
    ('system',system),
    few_shot_prompt,
    ('human',"Input Document:\n{document}")
])

# %%
for message in final_propositions_prompt.invoke({"document":".....EXAMPLE DOCUMENT....."}).messages:
    print(message.content)
    print()
# Out:
# Please break down the following text into simple, self-contained propositions. Ensure that each proposition meets the following criteria:
#
#     1. (Important) Express a Single Fact: Each proposition should state one specific fact or claim.
#     2. (Important) Be Understandable Without Context: The proposition should be self-contained, meaning it can be understood without needing additional context.
#     3. (Important) Use Full Names, Not Pronouns: Avoid pronouns or ambiguous references; use full entity names.
#     4. (Important) Include Relevant Dates/Qualifiers: If applicable, include necessary dates, times, and qualifiers to make the fact precise.
#     5. (Important) Contain One Subject-Predicate Relationship: Focus on a single subject and its corresponding action or attribute, without conjunctions or multiple clauses.
#
#
# Example Document:
# In 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.
#
# Example Propositions:
# ['Neil Armstrong was an astronaut.', 'Neil Armstrong walked on the Moon in 1969.', 'Neil Armstrong was the first person to walk on the Moon.', 'Neil Armstrong walked on the Moon during the Apollo 11 mission.', 'The Apollo 11 mission occurred in 1969.']
#
# Input Document:
# .....EXAMPLE DOCUMENT.....

# %%
proposition_generator = final_propositions_prompt | structured_llm

# %%
propositions = []

# %%
for i in range(len(chunks)):
    response = proposition_generator.invoke({"document":chunks[i].page_content})
    for proposition in response.propositions:
        propositions.append(Document(page_content=proposition, metadata={"Title":"Leaning Tower of Pisa", "Source":"https://en.wikipedia.org/wiki/Leaning_Tower_of_Pisa", "chunk_id":i+1}))

# %%
len(propositions)
# Out:
# 58

# %%
import random

# %%
for proposition in random.sample(propositions,5):
    print(proposition.page_content)
# Out:
# The 2001 study noted an affinity between the tower and the bell tower of San Nicola in Pisa.
# The Leaning Tower of Pisa is the campanile of Pisa Cathedral.
# The softness of the foundation soil brought the tower to the verge of collapse.
# An engineering investigation in 2018 concluded that dynamic soil-structure interaction explained why the tower withstood earthquake tremors.
# The softness of the foundation soil helped to prevent significant destruction to the tower during earthquakes.

# %%
import pickle

# %%
with open("./data/propositions.pickle",'wb') as fp:
    pickle.dump(propositions,fp)

# %% [markdown]
# ### Quality Check

# %%
# data model
class GradePropositions(BaseModel):
    """Grade a given proposition on accuracy, clarity, completeness, and conciseness"""

    accuracy: int = Field(description="Rate from 1-10 based on how well the proposition reflects the original text.")

    clarity: int = Field(
        description="Rate from 1-10 based on how easy it is to understand the proposition without additional context."
    )

    completeness: int = Field(
        description="Rate from 1-10 based on whether the proposition includes necessary details (e.g., dates, qualifiers)."
    )

    conciseness: int = Field(
        description="Rate from 1-10 based on whether the proposition is concise without losing important information."
    )

    reasoning: str = Field(description="The full reasoning and thought process that justifies the given scores/ evaluation")

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
structured_llm = ChatOpenAI(model='gpt-5-mini', temperature=0).with_structured_output(GradePropositions)

# %%
evaluation_prompt_template = """
Please evaluate the following proposition based on the criteria below:

1. Accuracy: Rate from 1-10 based on how well the proposition reflects the original text.
2. Clarity: Rate from 1-10 based on how easy it is to understand the proposition without additional context.
3. Completeness: Rate from 1-10 based on whether the proposition includes necessary details (e.g., dates, qualifiers).
4. Conciseness: Rate from 1-10 based on whether the proposition is concise without losing important information.

Don't jump into scoring the proposition, clearly show your thought process.

---

Example:

Docs: In 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.

Propositons_1: Neil Armstrong was an astronaut.
Evaluation_1: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_2: Neil Armstrong walked on the Moon in 1969.
Evaluation_3: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_3: Neil Armstrong was the first person to walk on the Moon.
Evaluation_3: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_4: Neil Armstrong walked on the Moon during the Apollo 11 mission.
Evaluation_4: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_5: The Apollo 11 mission occurred in 1969.
Evaluation_5: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

---

New Input:

Proposition: 
"{proposition}"

Original Text: 
"{original_text}"
""".strip()

# %%
prompt = ChatPromptTemplate([
    ('system', evaluation_prompt_template),
])

# %%
proposition_evaluator = prompt | structured_llm

# %%
thresholds = {"accuracy": 7, "clarity": 7, "completeness": 7, "conciseness": 7}


def evaluate_proposition(proposition, original_text):
    response = proposition_evaluator.invoke({"proposition": proposition, "original_text": original_text})
    
    
    scores = {"accuracy": response.accuracy, "clarity": response.clarity, "completeness": response.completeness, "conciseness": response.conciseness}

    reasoning = response.reasoning

    return scores, reasoning


def passes_quality_check(scores):
    for category, score in scores.items():
        if score < thresholds[category]:
            return False
    return True

# %%
evaluated_propositions = []

# %%
for idx, proposition in enumerate(propositions):
    scores, reasoning = evaluate_proposition(proposition.page_content, chunks[proposition.metadata['chunk_id'] - 1].page_content)
    if passes_quality_check(scores):
        # Proposition passes quality check, keep it
        evaluated_propositions.append(proposition)
    else:
        # Proposition fails, discard or flag for further review
        print(f"{idx+1}) Propostion: {proposition.page_content}\nScores: {scores}")
        print(f"Reasoning:\n{reasoning}")
        print("-"*50)
# Out:
# 23) Propostion: The Leaning Tower of Pisa has 294 steps according to other counts.
# Scores: {'accuracy': 9, 'clarity': 10, 'completeness': 6, 'conciseness': 10}
# Reasoning:
# Thought process:
#
# - I compared the proposition to the original text. The original states: "The tower has 296 or 294 steps; the seventh floor has two fewer steps on the north-facing staircase." This explicitly gives two possible step counts (296 or 294) and notes an explanation for the difference (the seventh floor has two fewer steps on one staircase).
#
# - The proposition says: "The Leaning Tower of Pisa has 294 steps according to other counts." This aligns with one of the two counts given in the source (294) and frames it as an alternate/other count, which is consistent with the source language "296 or 294 steps." Therefore the proposition correctly reflects part of the source.
#
# Scoring justification:
# - Accuracy (9): The proposition is factually supported by the original text (294 is one of the counts). I did not give a perfect 10 only because the original explicitly presents two possible counts (296 or 294); the proposition asserts the 294 count without mentioning the primary alternative (296). However, the phrase "according to other counts" does capture that it is an alternate figure, so the statement is highly accurate.
#
# - Clarity (10): The sentence is clear and easy to understand without additional context.
#
# - Completeness (6): The proposition omits the alternative 296-step count and the explanatory detail about the seventh floor having two fewer steps on the north-facing staircase. Those details are relevant to fully reflect the original sentence, so completeness is moderate rather than high.
#
# - Conciseness (10): The proposition is concise and does not include unnecessary wording while conveying the intended meaning.
# --------------------------------------------------
# 25) Propostion: The tower began to lean during construction in the 12th century.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 6, 'conciseness': 10}
# Reasoning:
# Thought process and comparison to the original text:
#
# 1) Restate proposition and relevant parts of the original text:
# - Proposition: "The tower began to lean during construction in the 12th century."
# - Original: "The tower began to lean during construction in the 12th century, due to soft ground which could not properly support the structure's weight. It worsened through the completion of construction in the 14th century. By 1990, the tilt had reached 5.5 degrees. The structure was stabilized by remedial work between 1993 and 2001, which reduced the tilt to 3.97 degrees."
#
# 2) Check accuracy:
# - The proposition directly repeats the original statement that the leaning began during construction in the 12th century. This is a correct and faithful extract from the source. No factual error introduced. => Accuracy = 10.
#
# 3) Check clarity:
# - The sentence is simple, unambiguous, and easy to understand without extra context. => Clarity = 10.
#
# 4) Check completeness:
# - The original text contains additional relevant details: the cause (soft ground), that the lean worsened through completion in the 14th century, and later tilt measurements and remedial stabilization dates and effects. The proposition communicates one key fact but omits those other important qualifiers and subsequent history. Because it captures a central fact but leaves out notable context and causes, it is partially complete but not fully. => Completeness = 6.
#
# (Rationale for 6 rather than a lower score: the proposition conveys the primary time-related claim exactly, so it isn't minimal/incorrect — but several significant details from the original are missing, so it shouldn't be rated high on completeness.)
#
# 5) Check conciseness:
# - The proposition is brief and conveys the intended claim without excess wording. It does not include unnecessary detail given the single fact it asserts. It is concise while preserving the core information of that claim. => Conciseness = 10.
#
# Summary of scores: accuracy 10, clarity 10, completeness 6, conciseness 10.
# --------------------------------------------------
# 27) Propostion: Soft ground could not properly support the tower's weight.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 5, 'conciseness': 8}
# Reasoning:
# Thought process:
# - I compared the proposition to the original sentence: "The tower began to lean during construction in the 12th century, due to soft ground which could not properly support the structure's weight."
# - The proposition, "Soft ground could not properly support the tower's weight," is essentially a direct restatement of the causal clause in the original text. The meaning and wording align closely, so it is fully accurate with respect to that causal claim.
# - However, the original text places this cause in context (the leaning began during construction in the 12th century) and the broader passage includes additional important details (the leaning worsened through completion in the 14th century; tilt measurements by 1990; stabilization work between 1993–2001). The proposition omits all temporal and consequence details and thus is incomplete relative to the full original passage.
#
# Justification of scores:
# - Accuracy (10): The proposition correctly captures the causal fact stated in the source (soft ground could not support the structure's weight). There is no factual error or distortion in that claim.
# - Clarity (10): The sentence is simple and unambiguous; its meaning is immediately clear without extra context.
# - Completeness (5): It reflects the key causal point but omits important contextual information (when the leaning began — 12th century during construction — that it worsened through the 14th century, later tilt measurements, and later stabilization). Because the original contains several additional relevant details, the proposition is only partially complete.
# - Conciseness (8): The proposition is brief and expresses the main causal idea without redundancy. It does omit contextual details, which keeps it concise but also reduces completeness; therefore it is not given a perfect score.
# --------------------------------------------------
# 28) Propostion: The tower's lean worsened through the completion of construction in the 14th century.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 4, 'conciseness': 10}
# Reasoning:
# Thought process:
# - Compare proposition to original text: The original states that the tower began to lean during construction in the 12th century due to soft ground, and that the lean worsened through the completion of construction in the 14th century. The proposition states only that "The tower's lean worsened through the completion of construction in the 14th century."
# - Accuracy: The proposition directly reflects a sentence from the original and is factually correct (it did worsen through completion in the 14th century). It does not contradict the source, so accuracy is high (10).
# - Clarity: The proposition is a single clear sentence with an unambiguous meaning; no additional context is required to understand the claim (10).
# - Completeness: The proposition omits important details present in the original: when the leaning began (12th century), the reason (soft ground), and later relevant facts about the magnitude of tilt and stabilization work ending in 2001. Because it leaves out these contextual and qualifying details, completeness is low (4).
# - Conciseness: The proposition conveys its single point succinctly without extraneous wording, so it is very concise (10).
# --------------------------------------------------
# 32) Propostion: The identity of the architect of the tower is a subject of controversy.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 6, 'conciseness': 10}
# Reasoning:
# Step-by-step thought process:
#
# 1) Compare proposition to original text: The proposition is verbatim the opening sentence of the original text: "The identity of the architect of the tower is a subject of controversy." That makes it fully accurate with respect to the source statement (score 10).
#
# 2) Clarity: The sentence is straightforward and unambiguous—readers understand the claim without additional context (score 10).
#
# 3) Completeness: The proposition correctly states the main point but omits the important supporting details present in the original: the candidate names (Guglielmo and Bonanno Pisano), the evidence found in 1820, Pisano's biography, and the 2001 study pointing to Diotisalvi. Because the original provides context and specific claims that explain the controversy, the proposition is incomplete relative to the fuller account. It still conveys the core claim, so it is not minimal, but it lacks the qualifiers and evidence that would make it comprehensive (score 6).
#
# 4) Conciseness: The proposition is concise and does not include unnecessary wording; it communicates the idea efficiently (score 10).
#
# Overall: exact match to the original sentence yields perfect accuracy and clarity; it is concise but only moderately complete because it omits the detailed reasons and candidates that the original supplies.
# --------------------------------------------------
# 33) Propostion: The design of the tower had long been attributed to a man named Guglielmo.
# Scores: {'accuracy': 9, 'clarity': 10, 'completeness': 4, 'conciseness': 6}
# Reasoning:
# Thought process (do not jump to scores):
#
# 1) Compare proposition to the original text: The original says, "The design had long been attributed to a man named Guglielmo and to Bonanno Pisano..." The proposition states, "The design of the tower had long been attributed to a man named Guglielmo." That is a true statement drawn directly from the text, but the original explicitly names an additional common attribution (Bonanno Pisano) and discusses controversy and later scholarship (Diotisalvi) that the proposition omits.
#
# 2) Evaluate Accuracy: The proposition correctly reflects a claim made in the original text — that the design had long been attributed to Guglielmo. It does not contradict the source. Because it leaves out the co-attribution to Bonanno Pisano and the context of controversy and later study, it is not a complete representation of the original passage, but as a standalone factual claim it is accurate. Therefore accuracy is high but not perfect.
#
# 3) Evaluate Clarity: The sentence is straightforward and easy to understand. No specialized terms or ambiguous phrasing. Clarity is maximal.
#
# 4) Evaluate Completeness: The original contains additional relevant details: the co-attribution to Bonanno Pisano (a well-known 12th-century artist), the discovery of a cast bearing Pisano’s name, and a 2001 study suggesting Diotisalvi as the original architect. The proposition omits these points and thus misses significant context and qualifiers. It also does not indicate the controversy or the later reassessment. Therefore completeness is low.
#
# 5) Evaluate Conciseness: The proposition is concise, but the criterion here is conciseness without losing important information. Because the brevity omits important information (the co-attribution and later scholarship), the conciseness is somewhat penalized: it is concise but at the cost of leaving out material that would be important for a fuller understanding.
#
# Numeric justifications:
# - Accuracy = 9: Correct statement from the text, but not fully encompassing the complete attribution picture.
# - Clarity = 10: Clear and easily understood.
# - Completeness = 4: Omits major co-attribution and later findings; lacks context.
# - Conciseness = 6: Short and to the point, but loses important information that should be included for a complete summary.
# --------------------------------------------------
# 34) Propostion: The design of the tower had long been attributed to Bonanno Pisano.
# Scores: {'accuracy': 7, 'clarity': 10, 'completeness': 3, 'conciseness': 6}
# Reasoning:
# Thought process:
#
# 1) Compare proposition to original text:
#    - Original: "The identity of the architect of the tower is a subject of controversy. The design had long been attributed to a man named Guglielmo and to Bonanno Pisano..."
#    - Proposition: "The design of the tower had long been attributed to Bonanno Pisano."
#
# 2) Accuracy assessment (score = 7):
#    - The proposition is factually correct in that Bonanno Pisano was one of the people to whom the design was long attributed; the phrasing "had long been attributed to Bonanno Pisano" mirrors the original wording.
#    - It is somewhat misleading because the original explicitly states the design was also long attributed to another person (Guglielmo) and that the attribution is controversial and later challenged by a 2001 study favoring Diotisalvi. Because the proposition omits these important qualifiers, I do not give a top score but it is still substantially accurate.
#
# 3) Clarity assessment (score = 10):
#    - The proposition is simple and unambiguous. A reader can easily understand the claim without extra context.
#
# 4) Completeness assessment (score = 3):
#    - The proposition omits several key details from the original: the alternative attribution to Guglielmo, the controversy over the architect's identity, the 1820 cast evidence and its possible alternative explanation, and the 2001 study suggesting Diotisalvi as the original architect. These omissions make the statement incomplete relative to the full original text.
#
# 5) Conciseness assessment (score = 6):
#    - The proposition is concise, but conciseness here comes at the cost of omitting significant context and qualifiers. Because the criterion asks whether it is concise without losing important information, the loss of those details reduces the score.
#
# Overall: the proposition is a short, clear, partially accurate excerpt of the original, but it lacks important context and competing attributions mentioned in the source.
# --------------------------------------------------
# 35) Propostion: Bonanno Pisano was a well-known 12th-century resident artist of Pisa.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 6, 'conciseness': 10}
# Reasoning:
# Thought process:
# 1. Identify the claim in the proposition: "Bonanno Pisano was a well-known 12th-century resident artist of Pisa."
# 2. Locate corresponding text in the original: the original explicitly calls Bonanno Pisano "a well-known 12th-century resident artist of Pisa known for his bronze casting, particularly in the Pisa Duomo," and then gives additional biographical and evidentiary details (left for Monreale in 1185, returned and died in Pisa; a cast bearing his name found in 1820; controversy over whether he was the tower's architect).
# 3. Assess accuracy: The proposition directly matches an explicit phrase in the source. It does not introduce any false information or contradict the text. Therefore accuracy is maximal (10).
# 4. Assess clarity: The proposition is short and unambiguous; no additional context is needed to understand the statement. Clarity is therefore maximal (10).
# 5. Assess completeness: The proposition captures the core identity claim but omits several relevant details present in the original: his specialization in bronze casting (and association with the Pisa Duomo), the dates/biographical movements (left in 1185, returned and died), the discovery of a cast bearing his name in 1820, and the broader context that attribution of the tower is controversial. Because the proposition lacks these qualifiers and supporting details, completeness is moderate (6).
# 6. Assess conciseness: The proposition conveys the essential point with no unnecessary words, so conciseness is maximal (10).
# --------------------------------------------------
# 37) Propostion: Bonanno Pisano produced bronze casting for the Pisa Duomo.
# Scores: {'accuracy': 10, 'clarity': 9, 'completeness': 6, 'conciseness': 10}
# Reasoning:
# Thought process:
# 1. Restate the original relevant text: the passage says Bonanno Pisano was a well-known 12th-century Pisan artist "known for his bronze casting, particularly in the Pisa Duomo." It also notes a cast bearing his name was found near the tower but that evidence is ambiguous (could relate to a bronze door destroyed in 1595).
# 2. Compare proposition to the source: The proposition claims "Bonanno Pisano produced bronze casting for the Pisa Duomo." This directly matches the core claim in the text that he was known for bronze casting in the Pisa Duomo.
# 3. Consider nuances and possible mismatches:
#    - The original frames this as what he was "known for," and mentions some ambiguity about physical evidence; the proposition presents the activity as a straightforward fact without noting the uncertainty. This is a minor loss of nuance but does not contradict the source.
#    - The original specifies he was a 12th-century artist; the proposition omits temporal detail.
#    - The proposition's wording is slightly awkward ("produced bronze casting" vs more natural "produced bronze castings" or "created bronze works"), but the meaning is clear.
# 4. Rate each criterion based on the above:
#    - Accuracy (10): The proposition accurately reflects the main claim in the source that Pisano did bronze work for the Pisa Duomo.
#    - Clarity (9): The statement is understandable, though its phrasing is mildly awkward.
#    - Completeness (6): It omits context/qualifiers present in the source (the 12th-century timeframe and the mention of ambiguous evidence), so it is incomplete relative to the original.
#    - Conciseness (10): The proposition is brief and does not include unnecessary information.
# --------------------------------------------------
# 40) Propostion: Bonanno Pisano died in Pisa.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 5, 'conciseness': 10}
# Reasoning:
# Step-by-step thought process:
#
# 1) Locate relevant sentence(s) in the original text: The text says Pisano was a well-known 12th-century resident artist of Pisa, "left Pisa in 1185 for Monreale, Sicily, only to return and die in his home town." This directly states he returned and died in his hometown (Pisa).
#
# 2) Accuracy assessment: The proposition "Bonanno Pisano died in Pisa." directly matches the text's statement that he returned and died in his hometown, which is established as Pisa earlier. There is no contradiction or missing qualifier in the source that would make this false, so accuracy is 10/10.
#
# 3) Clarity assessment: The sentence is simple, unambiguous, and needs no extra context to be understood. Clarity is 10/10.
#
# 4) Completeness assessment: The original provides additional context and details (he left Pisa in 1185 for Monreale, Sicily, then returned and died in his hometown; he is a 12th-century resident artist). The proposition states only the fact of death in Pisa and omits the timeline and related context. Because important contextual details from the source are missing, completeness is moderate: 5/10.
#
# 5) Conciseness assessment: The proposition is brief and conveys the stated fact without unnecessary words. It is appropriately concise, so conciseness is 10/10.
# --------------------------------------------------
# 45) Propostion: The 2001 study cited the time of construction as a reason to attribute the tower to Diotisalvi.
# Scores: {'accuracy': 8, 'clarity': 10, 'completeness': 5, 'conciseness': 7}
# Reasoning:
# Step-by-step thought process:
#
# 1. Identify the claim in the proposition: "The 2001 study cited the time of construction as a reason to attribute the tower to Diotisalvi."
#
# 2. Compare with the original text: the text says "A 2001 study seems to indicate Diotisalvi was the original architect, due to the time of construction and affinity with other Diotisalvi works, notably the bell tower of San Nicola and the Baptistery, both in Pisa."
#
# 3. Check accuracy: The original explicitly lists "time of construction" as one of the reasons. Therefore the proposition correctly reports that the 2001 study cited time of construction as a reason. However, the original lists an additional reason (affinity with other works) and frames the conclusion as tentative ("seems to indicate"). The proposition omits the other stated reason and does not reflect the tentative wording. For those reasons I rate accuracy as 8/10 (correct but not fully faithful to nuance and additional reasons).
#
# 4. Check clarity: The sentence is straightforward and easy to understand without extra context. Score: 10/10.
#
# 5. Check completeness: The original gives both "time of construction" and "affinity with other Diotisalvi works" (with examples) as reasons and uses a cautious tone. The proposition mentions only one of the two reasons and omits the examples and the tentative phrasing. It therefore lacks important details. Score: 5/10.
#
# 6. Check conciseness: The proposition is concise and communicates a correct partial point. However, because it omits a significant additional reason from the source, it loses some important information. It is still fairly succinct. Score: 7/10.
#
# Summary: The proposition accurately captures one of the study's reasons but omits the other major reason and the cautious tone, making it clear but incomplete.
# --------------------------------------------------
# 46) Propostion: The 2001 study cited affinity with other Diotisalvi works as a reason to attribute the tower to Diotisalvi.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 6, 'conciseness': 7}
# Reasoning:
# Thought process and comparison to the source:
# - I first identified the claim in the proposition: that a 2001 study cited "affinity with other Diotisalvi works" as a reason to attribute the tower to Diotisalvi.
# - I located the relevant sentence in the original text: "A 2001 study seems to indicate Diotisalvi was the original architect, due to the time of construction and affinity with other Diotisalvi works, notably the bell tower of San Nicola and the Baptistery, both in Pisa."
# - Matching elements:
#   - The proposition correctly states the study year (2001) and that the study used affinity with other Diotisalvi works as a reason. This is directly supported by the source.
#   - The proposition correctly frames this as a reason to attribute the tower to Diotisalvi (the original says the study "seems to indicate" Diotisalvi was the original architect), so the causal relationship is accurate.
# - Missing or simplified elements:
#   - The original lists two reasons for the study's conclusion: the time of construction AND affinity with other Diotisalvi works. The proposition mentions only the affinity reason and omits the time-of-construction rationale.
#   - The original gives examples of the Diotisalvi works (bell tower of San Nicola and the Baptistery) which the study noted; the proposition does not include these examples. Depending on how much detail is required, those could be considered relevant omissions.
#   - The original frames the conclusion cautiously with "seems to indicate" (reflecting controversy); the proposition does not preserve that cautious tone explicitly but also does not overstate (it says "as a reason to attribute," which is similar in strength to the original claim).
# - Evaluation rationale for scores:
#   - Accuracy (10): The proposition accurately reflects a true part of the original sentence — that the 2001 study used affinity with other Diotisalvi works as a reason to attribute the tower to Diotisalvi. There is no factual error.
#   - Clarity (10): The proposition is straightforward and easily understood without additional context.
#   - Completeness (6): The proposition omits the other reason cited by the study (time of construction) and does not mention the example works; it also omits the cautious wording that the study "seems to indicate," which slightly reduces completeness. It does include the study year, which is useful.
#   - Conciseness (7): The proposition is concise, but because it omits an important additional rationale (time of construction) and examples, it loses some important information; therefore it is concise but not optimally so given the original.
# Overall, the proposition is accurate and clear but somewhat incomplete for leaving out additional reasons and examples provided in the source.
# --------------------------------------------------
# 47) Propostion: The 2001 study noted an affinity between the tower and the bell tower of San Nicola in Pisa.
# Scores: {'accuracy': 9, 'clarity': 10, 'completeness': 6, 'conciseness': 10}
# Reasoning:
# Thought process:
#
# 1) Identify the claim in the proposition and the corresponding sentence(s) in the original text.
#    - Proposition: "The 2001 study noted an affinity between the tower and the bell tower of San Nicola in Pisa."
#    - Original text: "A 2001 study seems to indicate Diotisalvi was the original architect, due to the time of construction and affinity with other Diotisalvi works, notably the bell tower of San Nicola and the Baptistery, both in Pisa."
#
# 2) Accuracy assessment:
#    - The original explicitly says the 2001 study observed an "affinity" with other Diotisalvi works, "notably the bell tower of San Nicola..." The proposition restates that the 2001 study noted an affinity between the (subject) tower and the bell tower of San Nicola. This is a faithful, direct reflection of the source.
#    - Minor nuance lost: the original frames the affinity as evidence pointing to Diotisalvi as the original architect and mentions affinity with multiple works (including the Baptistery). Because the proposition omits the attribution-to-Diotisalvi context and the other example, I deduct one point for loss of nuance. => accuracy = 9.
#
# 3) Clarity assessment:
#    - The proposition is short, unambiguous, and easily understood without additional context. => clarity = 10.
#
# 4) Completeness assessment:
#    - The original contains additional relevant details: the affinity is cited as part of the reason the study suggests Diotisalvi as the architect, and the study also notes affinity with the Baptistery. The proposition only mentions one of the cited affinities and omits the attribution conclusion. Therefore it is incomplete relative to the original text. It does include the date (2001) which is good. => completeness = 6.
#
# 5) Conciseness assessment:
#    - The proposition is concise and does not include unnecessary words; it conveys the stated point succinctly. => conciseness = 10.
#
# Summary: The proposition is accurate and clear but omits the explanatory conclusion (the study’s attribution to Diotisalvi) and the additional example (the Baptistery), so it loses some completeness.
# --------------------------------------------------
# 48) Propostion: The 2001 study noted an affinity between the tower and the Baptistery in Pisa.
# Scores: {'accuracy': 9, 'clarity': 10, 'completeness': 6, 'conciseness': 10}
# Reasoning:
# Thought process and comparison:
# - Original text: A 2001 study suggests Diotisalvi was the original architect of the tower, based on construction timing and an affinity with other Diotisalvi works, notably the bell tower of San Nicola and the Baptistery (both in Pisa).
# - Proposition: "The 2001 study noted an affinity between the tower and the Baptistery in Pisa."
#
# Evaluation details:
# - Accuracy (9): The proposition correctly states that the 2001 study noted an affinity involving the Baptistery in Pisa. The original specifically lists the Baptistery as one of the Diotisalvi works showing affinity, so the proposition is accurate. It loses a bit of nuance by omitting that the affinity was used to attribute the tower to Diotisalvi and that the affinity was with Diotisalvi's other works (including the bell tower of San Nicola), hence not a perfect 10.
#
# - Clarity (10): The sentence is straightforward and easily understood without extra context.
#
# - Completeness (6): The proposition omits important qualifiers and context from the original: that the affinity was cited as evidence Diotisalvi was the original architect, that the affinity was with Diotisalvi's works (not generically any affinity), and that the bell tower of San Nicola was another notable comparison. It also doesn't explicitly name the tower (though context implies the Pisa tower). It does include the year (2001), which helps.
#
# - Conciseness (10): The proposition is succinct and does not include extraneous information.
#
# Summary: The proposition is a clear and accurate but somewhat incomplete simplification of the original sentence—hence high scores for accuracy, clarity, and conciseness, but a lower score for completeness.
# --------------------------------------------------
# 51) Propostion: Dynamic soil-structure interaction influenced the tower's vibrational characteristics.
# Scores: {'accuracy': 9, 'clarity': 10, 'completeness': 4, 'conciseness': 7}
# Reasoning:
# Step-by-step thought process:
#
# 1) Compare proposition to original text.
#    - Original: A 2018 engineering investigation concluded that the tower withstood tremors because of dynamic soil-structure interaction: the height and stiffness of the tower combined with the softness of the foundation soil influence the tower's vibrational characteristics so it does not resonate with earthquake ground motion. The same soft soil caused the leaning but also helped prevent significant destruction. The tower has survived at least four strong earthquakes since 1280.
#    - Proposition: "Dynamic soil-structure interaction influenced the tower's vibrational characteristics."
#
# 2) Accuracy assessment (score: 9).
#    - The proposition directly reflects a central claim in the original: dynamic soil-structure interaction does influence the tower's vibrational characteristics. This is a faithful, correct restatement of that part of the text.
#    - It loses a bit of the original's causal emphasis (that this influence is the reason the tower withstood earthquakes by avoiding resonance) but the core factual claim is accurate. Hence not a perfect 10 but very high.
#
# 3) Clarity assessment (score: 10).
#    - The sentence is simple, unambiguous, and understandable without additional context. The terms used are standard and clear.
#
# 4) Completeness assessment (score: 4).
#    - The proposition omits several important details from the original: it does not state the practical consequence (that this prevented resonance with earthquake ground motion and helped the tower survive tremors), it omits the 2018 investigation attribution, any timing or frequency context (e.g., surviving at least four strong earthquakes since 1280), and the role of the soft foundation soil (which both caused the lean and helped prevent destruction).
#    - Because those qualifiers and consequences are significant to the meaning of the original passage, the proposition is incomplete.
#
# 5) Conciseness assessment (score: 7).
#    - The proposition is concise and expresses a single key point efficiently. However, because it omits important consequences and context, it sacrifices some essential information. Therefore it is concise but not optimally so relative to preserving important details.
#
# Overall: The proposition is a clear and accurate but minimal restatement of one part of the original. It would be improved by adding the consequence (preventing resonance/withstanding earthquakes) and perhaps the investigative attribution or mention of the soft foundation soil's dual role.
# --------------------------------------------------
# 52) Propostion: The height of the tower influenced the tower's vibrational characteristics.
# Scores: {'accuracy': 7, 'clarity': 10, 'completeness': 3, 'conciseness': 5}
# Reasoning:
# Thought process:
# 1) Identify key points in the original text: the 2018 investigation attributes the tower's seismic performance to dynamic soil-structure interaction. Specifically, the height and stiffness of the tower combined with the softness of the foundation soil influence the tower's vibrational characteristics so it does not resonate with earthquake ground motion. The soft soil both caused the leaning and helped prevent collapse during earthquakes.
#
# 2) Compare the proposition to the original: the proposition states only that "The height of the tower influenced the tower's vibrational characteristics." This is a true statement derived from the original (height is explicitly mentioned as one of the influencing factors), so it is accurate in the narrow sense. However, the original attributes the effect to a combination of height, stiffness, and soft foundation soil and ties it to earthquake resilience (non-resonance). The proposition omits the other factors (stiffness, soil) and the context (earthquakes, non-resonance), so it is incomplete.
#
# 3) Scoring rationale:
# - Accuracy (7): The proposition is correct but partial — it reflects one element of the original claim but ignores the combined interaction emphasized in the text. It is not false, but it does not fully represent the original claim.
# - Clarity (10): The sentence is simple and unambiguous; it is easy to understand without additional context.
# - Completeness (3): It omits important qualifiers and context (that stiffness and soil softness also influence vibrations, and that this interaction prevented resonance during earthquakes). These omissions significantly reduce completeness.
# - Conciseness (5): The proposition is concise, but because it omits key information that changes the meaning or significance of the claim, it cannot be considered concise without loss of important information. Therefore a middling score is given.
# --------------------------------------------------
# 53) Propostion: The stiffness of the tower influenced the tower's vibrational characteristics.
# Scores: {'accuracy': 7, 'clarity': 10, 'completeness': 4, 'conciseness': 10}
# Reasoning:
# Thought process and mapping to the original text:
#
# - Original text says the tower’s height and stiffness combined with the softness of the foundation soil influence the tower’s vibrational characteristics, preventing resonance with earthquake ground motion. It emphasizes dynamic soil-structure interaction and that the soft soil both caused leaning and helped prevent earthquake destruction.
# - The proposition states only: “The stiffness of the tower influenced the tower's vibrational characteristics.”
#
# Assessment by criterion:
#
# Accuracy (7):
# - The proposition is factually correct in that stiffness is one of the factors that affects vibrational characteristics, as the original states.
# - However, the original attributes the effect to a combination of height, stiffness, and soft foundation soil (dynamic soil-structure interaction). By isolating stiffness, the proposition is a partial representation of the original claim rather than a fully faithful restatement. Hence a moderate-high accuracy score rather than a perfect one.
#
# Clarity (10):
# - The sentence is simple, unambiguous, and easy to understand without additional context. It uses common terms and a straightforward structure.
#
# Completeness (4):
# - The proposition omits important qualifiers and context from the original: it leaves out the role of the tower’s height, the softness of the foundation soil, the dynamic interaction between soil and structure, and the consequential detail that this combination prevented resonance with earthquake ground motion. Those omissions reduce completeness.
#
# Conciseness (10):
# - The proposition is succinct and conveys a single idea without unnecessary wording. It is concise while not introducing extraneous information.
#
# Overall: the proposition is a clear and concise but incomplete summary — accurate in part but missing key contextual factors emphasized in the original text.
# --------------------------------------------------
# 54) Propostion: The softness of the foundation soil influenced the tower's vibrational characteristics.
# Scores: {'accuracy': 8, 'clarity': 10, 'completeness': 5, 'conciseness': 10}
# Reasoning:
# Thought process:
# 1) Identify what the original text says: a 2018 investigation concluded that dynamic soil-structure interaction (the tower's height and stiffness combined with the softness of the foundation soil) alters the tower's vibrational characteristics so it does not resonate with earthquake ground motion; the soft soil also caused the leaning but helped prevent major earthquake damage.
#
# 2) Compare the proposition to the original text:
# - Exact match: The proposition states that the softness of the foundation soil influenced the tower's vibrational characteristics. That is true and directly supported by the original text.
# - Omissions/nuance: The original emphasizes that it is the combination of the tower’s height and stiffness together with the soft foundation soil (dynamic soil-structure interaction) that produces the effect, not the softness alone. The original also relates this to why the tower survived earthquakes and notes the dual role of the soft soil (causing leaning but mitigating earthquake damage). The proposition omits these qualifiers and outcomes.
#
# 3) Evaluate against the four criteria:
# - Accuracy (8): The proposition is correct in asserting that the soft foundation soil influenced vibrational characteristics. It loses some points because it omits the important qualifier that this effect arises from the interaction of soil softness with the tower’s height and stiffness, which could imply the soil alone caused the effect.
# - Clarity (10): The statement is straightforward and easy to understand without additional context.
# - Completeness (5): The proposition misses key details from the original — the role of dynamic soil-structure interaction (height and stiffness interplay), the consequence (avoiding resonance with ground motion), and the context (earthquakes / survival). Therefore it is only partially complete.
# - Conciseness (10): The proposition is concise and does not include unnecessary words; it remains short while conveying a single clear idea.
#
# Overall: the proposition is a correct, clear, and concise excerpt of the original idea but lacks important qualifiers and contextual consequences, hence moderate deductions on accuracy and completeness.
# --------------------------------------------------
# 55) Propostion: The tower's vibrational characteristics prevented the tower from resonating with earthquake ground motion.
# Scores: {'accuracy': 8, 'clarity': 10, 'completeness': 3, 'conciseness': 6}
# Reasoning:
# Step-by-step reasoning:
# 1. Compare proposition to original text: The original says a 2018 engineering investigation concluded that dynamic soil-structure interaction — specifically the combination of the tower’s height and stiffness with soft foundation soil — influences the tower’s vibrational characteristics so that it does not resonate with earthquake ground motion. The proposition states: “The tower's vibrational characteristics prevented the tower from resonating with earthquake ground motion.”
#
# 2. Accuracy: The proposition captures the core claim that the tower’s vibrational characteristics (as influenced by soil-structure interaction) prevented resonance with earthquake ground motion. This is true to the original. However, it omits the causal explanation (dynamic soil-structure interaction; the role of soft foundation soil combined with height and stiffness) and the investigative source/timing. Because it conveys the main factual point but leaves out important causal context, I rate accuracy 8/10.
#
# 3. Clarity: The sentence is straightforward and easy to understand without additional context. There is no ambiguous phrasing. Rating: 10/10.
#
# 4. Completeness: The proposition omits several important details present in the original: that this conclusion came from a 2018 engineering investigation, that the mechanism is dynamic soil-structure interaction (height & stiffness combined with soft soil), and that the same soft soil caused the leaning while helping prevent destruction. It also omits historical context (survived at least four strong earthquakes since 1280). Because several key qualifiers and explanatory elements are missing, completeness is low. Rating: 3/10.
#
# 5. Conciseness: The proposition is concise and economical. However, in being concise it omits significant causal and contextual information that the original included. Since conciseness should be scored for brevity without losing important information, the sentence is concise but loses important details — therefore a middling score. Rating: 6/10.
# --------------------------------------------------
# 56) Propostion: The softness of the foundation soil caused the tower to lean.
# Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 5, 'conciseness': 10}
# Reasoning:
# Thought process and comparison to the original text:
#
# 1) Identify the relevant original text content:
# - The original states: "The same soft soil that caused the leaning and brought the tower to the verge of collapse..." and earlier explains the tower's survival in earthquakes is related to the softness of the foundation soil and dynamic soil-structure interaction.
#
# 2) Compare the proposition to the text:
# - Proposition: "The softness of the foundation soil caused the tower to lean."
# - This is a direct restatement of the original's claim that the soft soil caused the leaning. It captures that causal relationship explicitly.
#
# 3) Evaluate each criterion with justification:
# - Accuracy (10): The proposition accurately reflects a clear statement in the original text — the soft foundation soil is identified as the cause of the tower's lean.
# - Clarity (10): The sentence is simple and unambiguous; no additional context is needed to understand the claim.
# - Completeness (5): While the proposition is correct, it omits important context from the original (e.g., that the same soft soil also helped prevent earthquake destruction via dynamic soil-structure interaction, and details about the seismic history). As a standalone claim it is complete enough, but relative to the full original passage it leaves out significant related information.
# - Conciseness (10): The proposition is brief and conveys the intended meaning without unnecessary words.
#
# Overall: the statement is an accurate, clear, and concise extraction of one factual point from the original, but it does not include the broader context and qualifiers present in the source text, hence a moderate score for completeness.
# --------------------------------------------------
# 57) Propostion: The softness of the foundation soil brought the tower to the verge of collapse.
# Scores: {'accuracy': 9, 'clarity': 10, 'completeness': 4, 'conciseness': 6}
# Reasoning:
# Thought process:
# - What the original text says: The tower survived strong earthquakes due to dynamic soil-structure interaction: the combination of the tower's height/stiffness and the softness of the foundation soil changes its vibrational characteristics so it does not resonate with earthquake ground motion. The text also states that the same soft soil caused the leaning and "brought the tower to the verge of collapse," while simultaneously helping to prevent significant destruction during earthquakes.
#
# - What the proposition states: "The softness of the foundation soil brought the tower to the verge of collapse."
#
# Comparison and evaluation by criterion:
# 1) Accuracy (9): The proposition asserts a fact explicitly stated in the original text (that the soft soil brought the tower to the verge of collapse). That is correct. I did not give a full 10 because the original frames this as one part of a more complex picture (the soft soil both caused the leaning/verge-of-collapse and helped prevent earthquake destruction), so the proposition, while correct, omits that balancing context — but accuracy is primarily about correctness of the stated claim, so it rates high.
#
# 2) Clarity (10): The sentence is simple and unambiguous. A reader can understand the claim without additional context.
#
# 3) Completeness (4): The proposition is incomplete relative to the original text’s key points. The original emphasizes the dual role of the soft soil (causing leaning/verge-of-collapse but also preventing severe earthquake damage via altered vibrational behavior). The proposition captures only the negative effect and omits the critical explanation and the mitigating effect. It also omits the mechanism (dynamic soil-structure interaction) and the earthquake-survival context. Because important qualifiers and the countervailing effect are missing, completeness is low.
#
# 4) Conciseness (6): The proposition is concise, but per the instruction to rate conciseness based on being concise without losing important information, it loses significant nuance from the original (the dual role and the mechanism). Thus it’s concise in wording but not balanced in content; the score reflects that tradeoff.
# --------------------------------------------------

# %%
len(evaluated_propositions)
# Out:
# 37

# %%
with open("./data/evaluated_propositions.pickle",'wb') as fp:
    pickle.dump(evaluated_propositions,fp)

# %% [markdown]
# ### Embedding propositions in a vectorstore

# %%
from langchain_chroma import Chroma
from langchain_openai.embeddings import OpenAIEmbeddings

# %%
vectorstore_propositions = Chroma.from_documents(documents=evaluated_propositions,embedding=OpenAIEmbeddings(model="text-embedding-3-small"))

# %%
retriever_propositions = vectorstore_propositions.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
query = "how many people visit the tower each year?"

# %%
res_proposition = retriever_propositions.invoke(query)

# %%
for i, doc in enumerate(res_proposition):
    print(f"{i}) Content: {doc.page_content} --- chunk_id: {doc.metadata["chunk_id"]}")
# Out:
# 0) Content: The Leaning Tower of Pisa receives over 5 million visitors each year. --- chunk_id: 1
# 1) Content: The Leaning Tower of Pisa has become one of the most visited tourist attractions in the world. --- chunk_id: 1
# 2) Content: The tower survived at least four strong earthquakes since 1280. --- chunk_id: 4

# %%
# answer is clearly mentions in the top retrieved doc with no extra, un-relevant info

# %% [markdown]
# ### Comparison with larger chunks size

# %%
from langchain_core.vectorstores import InMemoryVectorStore

# %%
vectorstore_larger = InMemoryVectorStore.from_documents(documents=chunks, embedding=OpenAIEmbeddings(model="text-embedding-3-small"))

# %%
retriever_larger = vectorstore_larger.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
res_larger = retriever_larger.invoke(query)

# %%
for i, doc in enumerate(res_larger):
    print(f"{i}) Content: {doc.page_content} --- chunk_id: {doc.metadata["chunk_id"]}")
# Out:
# 0) Content: The tower began to lean during construction in the 12th century, due to soft ground which could not properly support the structure's weight. It worsened through the completion of construction in the 14th century. By 1990, the tilt had reached 5.5 degrees. The structure was stabilized by remedial work between 1993 and 2001, which reduced the tilt to 3.97 degrees. --- chunk_id: 2
# 1) Content: The Leaning Tower of Pisa, or simply the Tower of Pisa (torre di Pisa), is the campanile, or freestanding bell tower, of Pisa Cathedral. It is known for its nearly four-degree lean, the result of an unstable foundation. The tower is one of three structures in Pisa's Cathedral Square (Piazza del Duomo), which includes the cathedral and Pisa Baptistry. Over time, the tower has become one of the most visited tourist attractions in the world as well as an architectural icon of Italy, receiving over 5 million visitors each year.
#
# The height of the tower is 55.86 metres (183 feet 3 inches) from the ground on the low side and 56.67 m (185 ft 11 in) on the high side. The width of the walls at the base is 2.44 m (8 ft 0 in). Its weight is estimated at 14,500 tonnes (16,000 short tons). The tower has 296 or 294 steps; the seventh floor has two fewer steps on the north-facing staircase. --- chunk_id: 1
# 2) Content: The tower has survived at least four strong earthquakes since 1280. A 2018 engineering investigation concluded that the tower withstood the tremors because of dynamic soil-structure interaction: the height and stiffness of the tower combined with the softness of the foundation soil influences the tower's vibrational characteristics in such a way that it does not resonate with earthquake ground motion. The same soft soil that caused the leaning and brought the tower to the verge of collapse helped to prevent significant destruction in the event of an earthquake. --- chunk_id: 4

# %%
# 2nd doc contains the answer with a lot of unrelated info

# %% [markdown]
# Final Observations:
# - key pieces of information was lost during creation of propositions from larger chunks. The process is not deterministic as an LLM is used
# - evaluation of propositions was off at times
# - this technique seems to work well with direct questions; clear inquiry that asks for information, rather than complex queries

# %% [markdown]
# ### Comparison

# %% [markdown]
# | Aspect| Proposition-Based Retrieval | Simple Chunk Retrieval |
# |---|---|---|
# | Precision in Response | **High**: Delivers focused and direct answers. | **Medium**: Provides more context but may include irrelevant information. |
# | Clarity and Brevity | **High**: Clear and concise, avoids unnecessary details. | **Medium**: More comprehensive but can be overwhelming. |
# | Contextual Richness | **Low**: May lack context, focusing on specific propositions. | **High**: Provides additional context and details. |
# | Comprehensiveness | **Low**: May omit broader context or supplementary details. | **High**: Offers a more complete view with extensive information. |
# | Narrative Flow | **Medium**: Can be fragmented or disjointed. | **High**: Preserves the logical flow and coherence of the original document. |
# | Information Overload | **Low**: Less likely to overwhelm with excess information. | **High**: Risk of overwhelming the user with too much information. |
# | Use Case Suitability | Best for quick, factual queries. | Best for complex queries requiring in-depth understanding. |
# | Efficiency | **High**: Provides quick, targeted responses. | **Medium**: May require more effort to sift through additional content. |
# | Specificity | **High**: Precise and targeted responses. | **Medium**: Answers may be less targeted due to inclusion of broader context. |
